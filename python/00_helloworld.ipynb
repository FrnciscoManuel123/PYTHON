# %%
#este simbolo se utiliza para comentar el codigo
print("hola grupo 430 de la carrera tecnica de programacion ")
#como consultar el tipo de datos
print(type("soy un doto str"))#tipo String
print(type(5))# tipo int
print(type(1.5))# tipo float
print(type(3+1j))#tipo complex
print(type(True))#tipo bool
print(type(print("mi cadena de texto")))#tipo novetype
