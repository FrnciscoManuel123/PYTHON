# %%
from os import name
### Vriables ###
#my_string_variable = "My String Variable"
#print(my_string_variable)

#my_int_variable = 5
#print(my_int_variable)

#my_int_to_str_variable= str(my_int_variable)
#print(my_int_to_str_variable)
#print(type(my_int_to_str_variable))

#my_bool_variable = False
#print(my_bool_variable)

#concatetacion de varioables en un print
#print(my_string_variable, my_int_to_str_variable, my_bool_variable)
#print("este es el valor de :", my_bool_variable)

#algunasfunciones del sistema
#print(len(my_string_variable))

#variables en una sola liena !cuidado con abusar de esta sintaxsis
#name, surname, alias, age ="grupo","programacion","CECYTEM" , 35
#print( "me llame:",name,surname, "   mi edad es :", age, "    y el alias es :", alias )

#inputa
#name = input ("cual es tu nombrre?")
#age = input ("cuantos años tiene?")
#print (name)#
#print (age)

#cambio su tipo
#name = 35
#age = "carlos"
#print(name)
#printg(age)

#forzamos el tipo?
address: str ="mi direccion"
address = True
eddress = 5
address = 1.2
print(type(address))
# Out:
# <class 'float'>
